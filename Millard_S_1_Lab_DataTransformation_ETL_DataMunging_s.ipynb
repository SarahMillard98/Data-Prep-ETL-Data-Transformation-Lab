# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-Analytics-Lifecycle" data-toc-modified-id="Data-Analytics-Lifecycle-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data Analytics Lifecycle</a></span></li><li><span><a href="#ETL-(Extract-Transform-Loading):-What?-Why?" data-toc-modified-id="ETL-(Extract-Transform-Loading):-What?-Why?-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>ETL (Extract Transform Loading): What? Why?</a></span><ul class="toc-item"><li><span><a href="#Garbage-In,-Garbage-Out" data-toc-modified-id="Garbage-In,-Garbage-Out-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Garbage In, Garbage Out</a></span></li></ul></li><li><span><a href="#How-much-time-do-data-analysts-spend-cleaning-and-transforming-data?" data-toc-modified-id="How-much-time-do-data-analysts-spend-cleaning-and-transforming-data?-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>How much time do data analysts spend cleaning and transforming data?</a></span></li><li><span><a href="#This-ETL-module-will-cover:" data-toc-modified-id="This-ETL-module-will-cover:-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>This ETL module will cover:</a></span></li><li><span><a href="#Different-data-types" data-toc-modified-id="Different-data-types-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Different data types</a></span></li><li><span><a href="#Basic-ETL-techniques" data-toc-modified-id="Basic-ETL-techniques-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Basic ETL techniques</a></span></li><li><span><a href="#Titanic-Dataset" data-toc-modified-id="Titanic-Dataset-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Titanic Dataset</a></span></li><li><span><a href="#Essential-Data-Transformation" data-toc-modified-id="Essential-Data-Transformation-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Essential Data Transformation</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Finding-out-data-type-&amp;-missing-values" data-toc-modified-id="Finding-out-data-type-&amp;-missing-values-8.0.1"><span class="toc-item-num">8.0.1&nbsp;&nbsp;</span>Finding out data type &amp; missing values</a></span></li><li><span><a href="#Basic-statistics" data-toc-modified-id="Basic-statistics-8.0.2"><span class="toc-item-num">8.0.2&nbsp;&nbsp;</span>Basic statistics</a></span></li><li><span><a href="#Remove-(unnessary)-columns" data-toc-modified-id="Remove-(unnessary)-columns-8.0.3"><span class="toc-item-num">8.0.3&nbsp;&nbsp;</span>Remove (unnessary) columns</a></span></li><li><span><a href="#Handling-missing-value" data-toc-modified-id="Handling-missing-value-8.0.4"><span class="toc-item-num">8.0.4&nbsp;&nbsp;</span>Handling missing value</a></span></li><li><span><a href="#Handling-Inaccurate/Inconsistent-Data" data-toc-modified-id="Handling-Inaccurate/Inconsistent-Data-8.0.5"><span class="toc-item-num">8.0.5&nbsp;&nbsp;</span>Handling Inaccurate/Inconsistent Data</a></span></li></ul></li></ul></li><li><span><a href="#Intermediate-level-Data-Transformation" data-toc-modified-id="Intermediate-level-Data-Transformation-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Intermediate-level Data Transformation</a></span></li></ul></div>

# %% [markdown]
# Sarah Millard
# "On my honor, as a student, I have neither given nor received unauthorized aid on this academic work."

# %% [markdown]
# # Data Analytics Lifecycle

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/b9/CRISP-DM_Process_Diagram.png" width=600>
# <img src="http://www.dataprix.com/files/CRISPDM/Metodologia_CRISP_DM1_html_52cdbecf.png" width=800>

# %% [markdown]
# **Data understanding and data preparation** are two important phases in data analytics project.
#
# These two stages are also called **"Extract Transform Loading" (ETL)**

# %% [markdown]
# # ETL (Extract Transform Loading): What? Why?
# ETL represents a broad range of data transformation and processing techniques. ETL involves cleaning and transforming the data for data analysis.
#
# ## Garbage In, Garbage Out##
#
# Similar terms include **data munging**, **wrangling**, and **data transformation**
#
# * Original data are not ready for analysis
# * A typical data set or source contains many data quality issues
#     * Missing values
#     * Inconsistency
#     * Inaccuracy
#     * …
# * Data preparation (or transformation) is a must

# %% [markdown]
# <img src="images/etl.gif">

# %% [markdown]
# # How much time do data analysts spend cleaning and transforming data?
#
# <img src="images/Time1.jpg">
# <img src="images/Time2.jpg">

# %% [markdown]
# # This ETL module will cover:
#
# * Basic techniques (data cleaning)
# * Intermediate-level techniques (data transformation)
# * Advanced techniques (data integration)

# %% [markdown]
# # Different data types
#
# * **Numerical** refers to integer and real
#     * Integer number (int): age
#     * Real number (float): price
# * **Object (or string)**
#     * **Nominal** or polynominal means there are more than two different values in the attributes. For example, Maritial_Status (single, married, divorced), school year (freshman, sophomore, junior, senior)
#     * **Binominal** means only two values. For example, Exam grade (Pass, Fail), Admission (Acceptance, Rejection), Purchase (Yes, Or), Cheating (True, False)

# %% [markdown]
# # Basic ETL techniques
# This covers basic ETL techniques
#
# Relevant online resources: 10 Minutes to pandas
# * Numerical columns http://pandas.pydata.org/pandas-docs/stable/10min.html
# * Categorical columns http://pandas-docs.github.io/pandas-docs-travis/categorical.html

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('2e-eXJ6HgkQ')

# %% [markdown]
# # Titanic Dataset
#
# <img src="images/titanic_datadescription.gif">

# %%
# import python packages
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
# import titanic_train.csv
ti=pd.read_csv("data/titanic_train.csv")
ti.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex     Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22.00      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  350.00      1
# 2                             Heikkinen, Miss. Laina      hi   26.00      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   hello   35.00      1
# 4                           Allen, Mr. William Henry    male    0.35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Essential Data Transformation

# %% [markdown]
# ### Finding out data type & missing values

# %%
#data types & missing values
ti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# **Numerical columns**: PassengerId, Survived, Pclass, Age, SibSp, Parch, Fare
#
# **Categorial columns**: Name, Sex, Ticket, Cabin, Embarked
#
# There are some **missing values (Age, Cabin, Embarked)**
#
# **This dataset needs data cleaning & transformation**

# %% [markdown]
# ### Basic statistics

# %%
#Describe shows a quick statistic summary of your data
#this is a good way to examine the numerical columns
ti.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   30.087563    0.523008
# std     257.353842    0.486592    0.836071   18.863424    1.102743
# min       1.000000    0.000000    1.000000    0.350000    0.000000
# 25%     223.500000    0.000000    2.000000   20.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000  350.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# There are a number of **data quality issues**
# - Someone or some people are 350 years old

# %%
ti.hist(figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11fc09b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e051a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fd0fdd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11fd46ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fd85e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fdbab10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1204bef50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1204f3b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1204fb690>]],
#       dtype=object)

# %%
# describe for a single column
ti['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
# do this for categorical columns
ti['Embarked'].describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %% [markdown]
# - Three different ports of departure (C = Cherbourg; Q = Queenstown; S = Southhampton)
# - S is the most popular port. 644 boared on Titanic from S

# %%
ti.groupby('Embarked').size()
# Out:
# Embarked
# C    168
# Q     77
# S    644
# dtype: int64

# %%
# how many unique values in the Sex column
ti.groupby('Sex').size()
# Out:
# Sex
# 0    312
# 1    578
# dtype: int64

# %% [markdown]
# ** Is there any data quality issue here?**

# %% [markdown]
# ### Remove (unnessary) columns

# %%
# remove an unnecessary column (PassengerId)

ti = ti.drop('PassengerId', axis=1)
ti.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex     Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male   22.00      1      0         A/5 21171   7.2500   NaN        S
# 1  female  350.00      1      0          PC 17599  71.2833   C85        C
# 2      hi   26.00      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3   hello   35.00      1      0            113803  53.1000  C123        S
# 4    male    0.35      0      0            373450   8.0500   NaN        S

# %%
# remove multiple columns (Name, Ticket, Cabin)

ti = ti.drop(['Name','Ticket'], axis=1)
ti.head()
# Out:
#    Survived  Pclass     Sex     Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male   22.00      1      0   7.2500   NaN        S
# 1         1       1  female  350.00      1      0  71.2833   C85        C
# 2         1       3      hi   26.00      0      0   7.9250   NaN        S
# 3         1       1   hello   35.00      1      0  53.1000  C123        S
# 4         0       3    male    0.35      0      0   8.0500   NaN        S

# %%
# can you remove Cabin column? (this column is not much useful for further analysis - predictive analytics)
ti = ti.drop('Cabin', axis=1)
ti.head()
# Out:
#    Survived  Pclass     Sex     Age  SibSp  Parch     Fare Embarked
# 0         0       3    male   22.00      1      0   7.2500        S
# 1         1       1  female  350.00      1      0  71.2833        C
# 2         1       3      hi   26.00      0      0   7.9250        S
# 3         1       1   hello   35.00      1      0  53.1000        S
# 4         0       3    male    0.35      0      0   8.0500        S

# %%
# how many missing values in each column or variable
ti.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %% [markdown]
# ### Handling missing value
#
# There are different ways to handle missing values
# - drop them all
# - replace with certain values (e.g., mean, mode, median, specific value)
#
# Recommended heuristics for handling missing values in real-world datasets
#
# 1. Remove unnecessary (or unmeaningful) columns (e.g., Ticket number): "unnecessary" means those columns you don't consider for the analysis. For example, it is obvious that there is no need to analyze "ticker numbers".
# 2. Some columns' missing values could be replaced with a specific value (e.g., mean, median), while replacement is not possible for other columns. For the latter case, drop the rows with missing values "mindfully".

# %%
#handling missing value: remove the rows with any missing value
ti_rev = ti.dropna()
ti_rev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  712 non-null    int64
#  1   Pclass    712 non-null    int64
#  2   Sex       712 non-null    object
#  3   Age       712 non-null    float64
#  4   SibSp     712 non-null    int64
#  5   Parch     712 non-null    int64
#  6   Fare      712 non-null    float64
#  7   Embarked  712 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 50.1+ KB

# %% [markdown]
# Now, the dataset has 712 rows. No rows with missing values. This is an aggressive approach.

# %%
# replace null value with the most popular value in a categorial columns
ti = ti.fillna({'Embarked': 'S'})
ti.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      0
# dtype: int64

# %%
ti['Age'].median()
# Out:
# 28.0

# %%
# replace null value with the median value 
ti = ti.fillna({'Age': 28})
ti.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
# what would you do to replace null values with the mean value
ti['Age'].mean()
# Out:
# 29.67286195286195

# %%
ti = ti.fillna({'Age': 29.67286195286195})
ti.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# ### Handling Inaccurate/Inconsistent Data
# - replace inaccurate values with null values and remove the row(s) with missing values
# - replace inaccurate values with different values

# %%
# hello in Sex is inaccurate ...replacing inaccurate value with null value
ti = ti.replace('hello', np.nan)
ti.head()
# Out:
#    Survived  Pclass     Sex     Age  SibSp  Parch     Fare Embarked
# 0         0       3    male   22.00      1      0   7.2500        S
# 1         1       1  female  350.00      1      0  71.2833        C
# 2         1       3      hi   26.00      0      0   7.9250        S
# 3         1       1     NaN   35.00      1      0  53.1000        S
# 4         0       3    male    0.35      0      0   8.0500        S

# %%
ti = ti.dropna()
ti.head()
# Out:
#    Survived  Pclass     Sex     Age  SibSp  Parch     Fare Embarked
# 0         0       3    male   22.00      1      0   7.2500        S
# 1         1       1  female  350.00      1      0  71.2833        C
# 2         1       3      hi   26.00      0      0   7.9250        S
# 4         0       3    male    0.35      0      0   8.0500        S
# 5         0       3    male   28.00      0      0   8.4583        Q

# %%
# 350 is an inaccurate value for age and should be replaced by 35
# changinge single value with replace
ti = ti.replace({'Age': 350}, {'Age': 35})
ti.head()
# Out:
#    Survived  Pclass     Sex    Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.00      1      0   7.2500        S
# 1         1       1  female  35.00      1      0  71.2833        C
# 2         1       3      hi  26.00      0      0   7.9250        S
# 4         0       3    male   0.35      0      0   8.0500        S
# 5         0       3    male  28.00      0      0   8.4583        Q

# %%
# instead of replacing hello with null value and removing the row, 
# can you replace hi with the most popular value (male) in the categorical column?
ti = ti.replace('hi', 'male')
ti.head()
# Out:
#    Survived  Pclass     Sex    Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.00      1      0   7.2500        S
# 1         1       1  female  35.00      1      0  71.2833        C
# 2         1       3    male  26.00      0      0   7.9250        S
# 4         0       3    male   0.35      0      0   8.0500        S
# 5         0       3    male  28.00      0      0   8.4583        Q

# %%
# Now, there should be male and female in the Sex column

# chaing categorical values with map
ti['Sex'] = ti['Sex'].map({'female': 0, 'male': 1})
ti.head()
# Out:
#    Survived  Pclass  Sex    Age  SibSp  Parch     Fare Embarked
# 0         0       3    1  22.00      1      0   7.2500        S
# 1         1       1    0  35.00      1      0  71.2833        C
# 2         1       3    1  26.00      0      0   7.9250        S
# 4         0       3    1   0.35      0      0   8.0500        S
# 5         0       3    1  28.00      0      0   8.4583        Q

# %%
# when you analyze data, it is better to transform categorical values to numerical values
# can you convert S, C, Q (Embarked) to 1, 2, 3
ti['Embarked'] = ti['Embarked'].map({'S' : 1, 'C' : 2, 'Q' : 3})
ti.head()
# Out:
#    Survived  Pclass  Sex    Age  SibSp  Parch     Fare  Embarked
# 0         0       3    1  22.00      1      0   7.2500         1
# 1         1       1    0  35.00      1      0  71.2833         2
# 2         1       3    1  26.00      0      0   7.9250         1
# 4         0       3    1   0.35      0      0   8.0500         1
# 5         0       3    1  28.00      0      0   8.4583         3

# %% [markdown]
# After applying multiple techniques of data cleaning, the data looks good now. Perhaps, this cleaned data can be used for analysis & builing predictive model.
# The predictive model would predict who is likely to survive, while using Survived as y value

# %%
# if the data cleaning is done, you may want to export it as csv or excel

ti.to_csv("data/ti_cleaned.csv")

# %% [markdown]
# # Intermediate-level Data Transformation

# %%
# create new columns
ti['CurrentAge'] = ti['Age'] + 90
ti.head()
# Out:
#    Survived  Pclass  Sex    Age  SibSp  Parch     Fare  Embarked  CurrentAge
# 0         0       3    1  22.00      1      0   7.2500         1      112.00
# 1         1       1    0  35.00      1      0  71.2833         2      125.00
# 2         1       3    1  26.00      0      0   7.9250         1      116.00
# 4         0       3    1   0.35      0      0   8.0500         1       90.35
# 5         0       3    1  28.00      0      0   8.4583         3      118.00

# %%
# can you create a new column ("discount") based on Fare?
# discount = Fare * 0.25
ti['Discount'] = ti['Fare'] * 0.25
ti.head()
# Out:
#    Survived  Pclass  Sex    Age  SibSp  Parch     Fare  Embarked  CurrentAge  \
# 0         0       3    1  22.00      1      0   7.2500         1      112.00
# 1         1       1    0  35.00      1      0  71.2833         2      125.00
# 2         1       3    1  26.00      0      0   7.9250         1      116.00
# 4         0       3    1   0.35      0      0   8.0500         1       90.35
# 5         0       3    1  28.00      0      0   8.4583         3      118.00
#
#     Discount
# 0   1.812500
# 1  17.820825
# 2   1.981250
# 4   2.012500
# 5   2.114575

# %%
# create a copy of existing column
ti['DeparturePort'] = ti['Embarked']
ti.head()
# Out:
#    Survived  Pclass  Sex    Age  SibSp  Parch     Fare  Embarked  CurrentAge  \
# 0         0       3    1  22.00      1      0   7.2500         1      112.00
# 1         1       1    0  35.00      1      0  71.2833         2      125.00
# 2         1       3    1  26.00      0      0   7.9250         1      116.00
# 4         0       3    1   0.35      0      0   8.0500         1       90.35
# 5         0       3    1  28.00      0      0   8.4583         3      118.00
#
#     Discount  DeparturePort
# 0   1.812500              1
# 1  17.820825              2
# 2   1.981250              1
# 4   2.012500              1
# 5   2.114575              3

# %%
# rename columns
ti = ti.rename(columns={'Pclass': 'PassengerClass'})
ti.head()
# Out:
#    Survived  PassengerClass  Sex    Age  SibSp  Parch     Fare  Embarked  \
# 0         0               3    1  22.00      1      0   7.2500         1
# 1         1               1    0  35.00      1      0  71.2833         2
# 2         1               3    1  26.00      0      0   7.9250         1
# 4         0               3    1   0.35      0      0   8.0500         1
# 5         0               3    1  28.00      0      0   8.4583         3
#
#    CurrentAge   Discount  DeparturePort
# 0      112.00   1.812500              1
# 1      125.00  17.820825              2
# 2      116.00   1.981250              1
# 4       90.35   2.012500              1
# 5      118.00   2.114575              3

# %%
# Can you rename discount as Disc
ti = ti.rename(columns={'Discount' : 'Disc'})
ti.head()
# Out:
#    Survived  PassengerClass  Sex    Age  SibSp  Parch     Fare  Embarked  \
# 0         0               3    1  22.00      1      0   7.2500         1
# 1         1               1    0  35.00      1      0  71.2833         2
# 2         1               3    1  26.00      0      0   7.9250         1
# 4         0               3    1   0.35      0      0   8.0500         1
# 5         0               3    1  28.00      0      0   8.4583         3
#
#    CurrentAge       Disc  DeparturePort
# 0      112.00   1.812500              1
# 1      125.00  17.820825              2
# 2      116.00   1.981250              1
# 4       90.35   2.012500              1
# 5      118.00   2.114575              3

# %%
# create bins (discretize)

ti['Fare_Category'] = pd.qcut(ti['Fare'], 5)
ti.head()
# Out:
#    Survived  PassengerClass  Sex    Age  SibSp  Parch     Fare  Embarked  \
# 0         0               3    1  22.00      1      0   7.2500         1
# 1         1               1    0  35.00      1      0  71.2833         2
# 2         1               3    1  26.00      0      0   7.9250         1
# 4         0               3    1   0.35      0      0   8.0500         1
# 5         0               3    1  28.00      0      0   8.4583         3
#
#    CurrentAge       Disc  DeparturePort      Fare_Category
# 0      112.00   1.812500              1    (-0.001, 7.854]
# 1      125.00  17.820825              2  (39.688, 512.329]
# 2      116.00   1.981250              1      (7.854, 10.5]
# 4       90.35   2.012500              1      (7.854, 10.5]
# 5      118.00   2.114575              3      (7.854, 10.5]

# %%
ti.groupby('Fare_Category').size()
# Out:
# Fare_Category
# (-0.001, 7.854]      179
# (7.854, 10.5]        184
# (10.5, 21.317]       171
# (21.317, 39.688]     181
# (39.688, 512.329]    175
# dtype: int64

# %%
#rename the name of those bins to 1, 2, 3, 4, 5
ti['Fare_Category_Labels'] = pd.qcut(ti['Fare'], 5, labels=['1', '2', '3', '4', '5'])
ti.head()
# Out:
#    Survived  PassengerClass  Sex    Age  SibSp  Parch     Fare  Embarked  \
# 0         0               3    1  22.00      1      0   7.2500         1
# 1         1               1    0  35.00      1      0  71.2833         2
# 2         1               3    1  26.00      0      0   7.9250         1
# 4         0               3    1   0.35      0      0   8.0500         1
# 5         0               3    1  28.00      0      0   8.4583         3
#
#    CurrentAge       Disc  DeparturePort      Fare_Category  \
# 0      112.00   1.812500              1    (-0.001, 7.854]
# 1      125.00  17.820825              2  (39.688, 512.329]
# 2      116.00   1.981250              1      (7.854, 10.5]
# 4       90.35   2.012500              1      (7.854, 10.5]
# 5      118.00   2.114575              3      (7.854, 10.5]
#
#   Fare_Category_Labels
# 0                    1
# 1                    5
# 2                    2
# 4                    2
# 5                    2

# %%
#Survived is categorical data type. What if I want to change it to integer
ti['Survived'] = ti['Survived'].astype(int)
ti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 890 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Survived              890 non-null    int64
#  1   PassengerClass        890 non-null    int64
#  2   Sex                   890 non-null    int64
#  3   Age                   890 non-null    float64
#  4   SibSp                 890 non-null    int64
#  5   Parch                 890 non-null    int64
#  6   Fare                  890 non-null    float64
#  7   Embarked              890 non-null    int64
#  8   CurrentAge            890 non-null    float64
#  9   Disc                  890 non-null    float64
#  10  DeparturePort         890 non-null    int64
#  11  Fare_Category         890 non-null    category
#  12  Fare_Category_Labels  890 non-null    category
# dtypes: category(2), float64(4), int64(7)
# memory usage: 85.6 KB

# %%
# filtering or selecting columns

#selecting two columns and assigning to a new variable or dataset called "ti_2"
ti_2 = ti[['Survived','Age']]
ti_2.head()
# Out:
#    Survived    Age
# 0         0  22.00
# 1         1  35.00
# 2         1  26.00
# 4         0   0.35
# 5         0  28.00

# %%
# can you select two other columns. use a different variable name (ti_3)
ti_3 = ti[['Age', 'CurrentAge']]
ti_3.head()
# Out:
#      Age  CurrentAge
# 0  22.00      112.00
# 1  35.00      125.00
# 2  26.00      116.00
# 4   0.35       90.35
# 5  28.00      118.00

# %%
# Filtering or Selecting rows

#single criterion
ti[(ti['Fare'] > 200)]
# Out:
#      Survived  PassengerClass  Sex   Age  SibSp  Parch      Fare  Embarked  \
# 27          0               1    1  19.0      3      2  263.0000         1
# 88          1               1    0  23.0      3      2  263.0000         1
# 118         0               1    1  24.0      0      1  247.5208         2
# 258         1               1    0  35.0      0      0  512.3292         2
# 299         1               1    0  50.0      0      1  247.5208         2
# 311         1               1    0  18.0      2      2  262.3750         2
# 341         1               1    0  24.0      3      2  263.0000         1
# 377         0               1    1  27.0      0      2  211.5000         2
# 380         1               1    0  42.0      0      0  227.5250         2
# 438         0               1    1  64.0      1      4  263.0000         1
# 527         0               1    1  28.0      0      0  221.7792         1
# 557         0               1    1  28.0      0      0  227.5250         2
# 679         1               1    1  36.0      0      1  512.3292         2
# 689         1               1    0  15.0      0      1  211.3375         1
# 700         1               1    0  18.0      1      0  227.5250         2
# 716         1               1    0  38.0      0      0  227.5250         2
# 730         1               1    0  29.0      0      0  211.3375         1
# 737         1               1    1  35.0      0      0  512.3292         2
# 742         1               1    0  21.0      2      2  262.3750         2
# 779         1               1    0  43.0      0      1  211.3375         1
#
#      CurrentAge        Disc  DeparturePort      Fare_Category  \
# 27        109.0   65.750000              1  (39.688, 512.329]
# 88        113.0   65.750000              1  (39.688, 512.329]
# 118       114.0   61.880200              2  (39.688, 512.329]
# 258       125.0  128.082300              2  (39.688, 512.329]
# 299       140.0   61.880200              2  (39.688, 512.329]
# 311       108.0   65.593750              2  (39.688, 512.329]
# 341       114.0   65.750000              1  (39.688, 512.329]
# 377       117.0   52.875000              2  (39.688, 512.329]
# 380       132.0   56.881250              2  (39.688, 512.329]
# 438       154.0   65.750000              1  (39.688, 512.329]
# 527       118.0   55.444800              1  (39.688, 512.329]
# 557       118.0   56.881250              2  (39.688, 512.329]
# 679       126.0  128.082300              2  (39.688, 512.329]
# 689       105.0   52.834375              1  (39.688, 512.329]
# 700       108.0   56.881250              2  (39.688, 512.329]
# 716       128.0   56.881250              2  (39.688, 512.329]
# 730       119.0   52.834375              1  (39.688, 512.329]
# 737       125.0  128.082300              2  (39.688, 512.329]
# 742       111.0   65.593750              2  (39.688, 512.329]
# 779       133.0   52.834375              1  (39.688, 512.329]
#
#     Fare_Category_Labels
# 27                     5
# 88                     5
# 118                    5
# 258                    5
# 299                    5
# 311                    5
# 341                    5
# 377                    5
# 380                    5
# 438                    5
# 527                    5
# 557                    5
# 679                    5
# 689                    5
# 700                    5
# 716                    5
# 730                    5
# 737                    5
# 742                    5
# 779                    5

# %%
#Multiple conditions have to be combined using & 
ti[(ti['Fare'] > 200) & (ti['Survived'] == 1)]
# Out:
#      Survived  PassengerClass  Sex   Age  SibSp  Parch      Fare  Embarked  \
# 88          1               1    0  23.0      3      2  263.0000         1
# 258         1               1    0  35.0      0      0  512.3292         2
# 299         1               1    0  50.0      0      1  247.5208         2
# 311         1               1    0  18.0      2      2  262.3750         2
# 341         1               1    0  24.0      3      2  263.0000         1
# 380         1               1    0  42.0      0      0  227.5250         2
# 679         1               1    1  36.0      0      1  512.3292         2
# 689         1               1    0  15.0      0      1  211.3375         1
# 700         1               1    0  18.0      1      0  227.5250         2
# 716         1               1    0  38.0      0      0  227.5250         2
# 730         1               1    0  29.0      0      0  211.3375         1
# 737         1               1    1  35.0      0      0  512.3292         2
# 742         1               1    0  21.0      2      2  262.3750         2
# 779         1               1    0  43.0      0      1  211.3375         1
#
#      CurrentAge        Disc  DeparturePort      Fare_Category  \
# 88        113.0   65.750000              1  (39.688, 512.329]
# 258       125.0  128.082300              2  (39.688, 512.329]
# 299       140.0   61.880200              2  (39.688, 512.329]
# 311       108.0   65.593750              2  (39.688, 512.329]
# 341       114.0   65.750000              1  (39.688, 512.329]
# 380       132.0   56.881250              2  (39.688, 512.329]
# 679       126.0  128.082300              2  (39.688, 512.329]
# 689       105.0   52.834375              1  (39.688, 512.329]
# 700       108.0   56.881250              2  (39.688, 512.329]
# 716       128.0   56.881250              2  (39.688, 512.329]
# 730       119.0   52.834375              1  (39.688, 512.329]
# 737       125.0  128.082300              2  (39.688, 512.329]
# 742       111.0   65.593750              2  (39.688, 512.329]
# 779       133.0   52.834375              1  (39.688, 512.329]
#
#     Fare_Category_Labels
# 88                     5
# 258                    5
# 299                    5
# 311                    5
# 341                    5
# 380                    5
# 679                    5
# 689                    5
# 700                    5
# 716                    5
# 730                    5
# 737                    5
# 742                    5
# 779                    5

# %% [markdown]
# Some passengers in upper class did not survived.

# %%
# can you create a filter using a criterion?
ti[(ti['Embarked'] == 1)]
# Out:
#      Survived  PassengerClass  Sex    Age  SibSp  Parch     Fare  Embarked  \
# 0           0               3    1  22.00      1      0   7.2500         1
# 2           1               3    1  26.00      0      0   7.9250         1
# 4           0               3    1   0.35      0      0   8.0500         1
# 6           0               1    1  54.00      0      0  51.8625         1
# 7           0               3    1   2.00      3      1  21.0750         1
# ..        ...             ...  ...    ...    ...    ...      ...       ...
# 883         0               2    1  28.00      0      0  10.5000         1
# 884         0               3    1  25.00      0      0   7.0500         1
# 886         0               2    1  27.00      0      0  13.0000         1
# 887         1               1    0  19.00      0      0  30.0000         1
# 888         0               3    0  28.00      1      2  23.4500         1
#
#      CurrentAge       Disc  DeparturePort      Fare_Category  \
# 0        112.00   1.812500              1    (-0.001, 7.854]
# 2        116.00   1.981250              1      (7.854, 10.5]
# 4         90.35   2.012500              1      (7.854, 10.5]
# 6        144.00  12.965625              1  (39.688, 512.329]
# 7         92.00   5.268750              1     (10.5, 21.317]
# ..          ...        ...            ...                ...
# 883      118.00   2.625000              1      (7.854, 10.5]
# 884      115.00   1.762500              1    (-0.001, 7.854]
# 886      117.00   3.250000              1     (10.5, 21.317]
# 887      109.00   7.500000              1   (21.317, 39.688]
# 888      118.00   5.862500              1   (21.317, 39.688]
#
#     Fare_Category_Labels
# 0                      1
# 2                      2
# 4                      2
# 6                      5
# 7                      3
# ..                   ...
# 883                    2
# 884                    1
# 886                    3
# 887                    4
# 888                    4
#
# [645 rows x 13 columns]

# %%
# sampling data randomly

# sampling 10 rows only (different samples for every time you run this cell)
ti_10 = ti.sample(10)
ti_10

# to have the same samples for every time 
# ti.sample(10, random_state = 1)
# Out:
#      Survived  PassengerClass  Sex   Age  SibSp  Parch     Fare  Embarked  \
# 363         0               3    1  35.0      0      0   7.0500         1
# 626         0               2    1  57.0      0      0  12.3500         3
# 693         0               3    1  25.0      0      0   7.2250         2
# 134         0               2    1  25.0      0      0  13.0000         1
# 40          0               3    0  40.0      1      0   9.4750         1
# 658         0               2    1  23.0      0      0  13.0000         1
# 771         0               3    1  48.0      0      0   7.8542         1
# 190         1               2    0  32.0      0      0  13.0000         1
# 473         1               2    0  23.0      0      0  13.7917         2
# 324         0               3    1  28.0      8      2  69.5500         1
#
#      CurrentAge       Disc  DeparturePort      Fare_Category  \
# 363       125.0   1.762500              1    (-0.001, 7.854]
# 626       147.0   3.087500              3     (10.5, 21.317]
# 693       115.0   1.806250              2    (-0.001, 7.854]
# 134       115.0   3.250000              1     (10.5, 21.317]
# 40        130.0   2.368750              1      (7.854, 10.5]
# 658       113.0   3.250000              1     (10.5, 21.317]
# 771       138.0   1.963550              1    (-0.001, 7.854]
# 190       122.0   3.250000              1     (10.5, 21.317]
# 473       113.0   3.447925              2     (10.5, 21.317]
# 324       118.0  17.387500              1  (39.688, 512.329]
#
#     Fare_Category_Labels
# 363                    1
# 626                    3
# 693                    1
# 134                    3
# 40                     2
# 658                    3
# 771                    1
# 190                    3
# 473                    3
# 324                    5

# %%
# sort data by column

#sorting: ascending=True is the default
ti_10.sort_values(by=['Fare'])
# Out:
#      Survived  PassengerClass  Sex   Age  SibSp  Parch     Fare  Embarked  \
# 363         0               3    1  35.0      0      0   7.0500         1
# 693         0               3    1  25.0      0      0   7.2250         2
# 771         0               3    1  48.0      0      0   7.8542         1
# 40          0               3    0  40.0      1      0   9.4750         1
# 626         0               2    1  57.0      0      0  12.3500         3
# 134         0               2    1  25.0      0      0  13.0000         1
# 658         0               2    1  23.0      0      0  13.0000         1
# 190         1               2    0  32.0      0      0  13.0000         1
# 473         1               2    0  23.0      0      0  13.7917         2
# 324         0               3    1  28.0      8      2  69.5500         1
#
#      CurrentAge       Disc  DeparturePort      Fare_Category  \
# 363       125.0   1.762500              1    (-0.001, 7.854]
# 693       115.0   1.806250              2    (-0.001, 7.854]
# 771       138.0   1.963550              1    (-0.001, 7.854]
# 40        130.0   2.368750              1      (7.854, 10.5]
# 626       147.0   3.087500              3     (10.5, 21.317]
# 134       115.0   3.250000              1     (10.5, 21.317]
# 658       113.0   3.250000              1     (10.5, 21.317]
# 190       122.0   3.250000              1     (10.5, 21.317]
# 473       113.0   3.447925              2     (10.5, 21.317]
# 324       118.0  17.387500              1  (39.688, 512.329]
#
#     Fare_Category_Labels
# 363                    1
# 693                    1
# 771                    1
# 40                     2
# 626                    3
# 134                    3
# 658                    3
# 190                    3
# 473                    3
# 324                    5

# %%
ti_10.sort_values(by=['Fare'], ascending=False)
# Out:
#      Survived  PassengerClass  Sex   Age  SibSp  Parch     Fare  Embarked  \
# 324         0               3    1  28.0      8      2  69.5500         1
# 473         1               2    0  23.0      0      0  13.7917         2
# 134         0               2    1  25.0      0      0  13.0000         1
# 658         0               2    1  23.0      0      0  13.0000         1
# 190         1               2    0  32.0      0      0  13.0000         1
# 626         0               2    1  57.0      0      0  12.3500         3
# 40          0               3    0  40.0      1      0   9.4750         1
# 771         0               3    1  48.0      0      0   7.8542         1
# 693         0               3    1  25.0      0      0   7.2250         2
# 363         0               3    1  35.0      0      0   7.0500         1
#
#      CurrentAge       Disc  DeparturePort      Fare_Category  \
# 324       118.0  17.387500              1  (39.688, 512.329]
# 473       113.0   3.447925              2     (10.5, 21.317]
# 134       115.0   3.250000              1     (10.5, 21.317]
# 658       113.0   3.250000              1     (10.5, 21.317]
# 190       122.0   3.250000              1     (10.5, 21.317]
# 626       147.0   3.087500              3     (10.5, 21.317]
# 40        130.0   2.368750              1      (7.854, 10.5]
# 771       138.0   1.963550              1    (-0.001, 7.854]
# 693       115.0   1.806250              2    (-0.001, 7.854]
# 363       125.0   1.762500              1    (-0.001, 7.854]
#
#     Fare_Category_Labels
# 324                    5
# 473                    3
# 134                    3
# 658                    3
# 190                    3
# 626                    3
# 40                     2
# 771                    1
# 693                    1
# 363                    1

# %%
# Ascending by first column, then descending by second column
ti_10.sort_values(by=['Survived','Age'], ascending=[1,0])

# %%
# you can expport this sample data 

ti_10.to_csv("data/ti_10.csv")

# %%
# can you sample 50 rows?

ti_50 = ti.sample(50)
ti_50
# Out:
#      Survived  PassengerClass  Sex    Age  SibSp  Parch      Fare  Embarked  \
# 465         0               3    1  38.00      0      0    7.0500         1
# 399         1               2    0  28.00      0      0   12.6500         1
# 93          0               3    1  26.00      1      2   20.5750         1
# 407         1               2    1   3.00      1      1   18.7500         1
# 1           1               1    0  35.00      1      0   71.2833         2
# 867         0               1    1  31.00      0      0   50.4958         1
# 725         0               3    1  20.00      0      0    8.6625         1
# 236         0               2    1  44.00      1      0   26.0000         1
# 130         0               3    1  33.00      0      0    7.8958         2
# 55          1               1    1  28.00      0      0   35.5000         1
# 537         1               1    0  30.00      0      0  106.4250         2
# 4           0               3    1   0.35      0      0    8.0500         1
# 319         1               1    0  40.00      1      1  134.5000         2
# 293         0               3    0  24.00      0      0    8.8500         1
# 851         0               3    1  74.00      0      0    7.7750         1
# 393         1               1    0  23.00      1      0  113.2750         2
# 375         1               1    0  28.00      1      0   82.1708         2
# 406         0               3    1  51.00      0      0    7.7500         1
# 317         0               2    1  54.00      0      0   14.0000         1
# 720         1               2    0   6.00      0      1   33.0000         1
# 768         0               3    1  28.00      1      0   24.1500         3
# 802         1               1    1  11.00      1      2  120.0000         1
# 840         0               3    1  20.00      0      0    7.9250         1
# 462         0               1    1  47.00      0      0   38.5000         1
# 45          0               3    1  28.00      0      0    8.0500         1
# 644         1               3    0   0.75      2      1   19.2583         2
# 769         0               3    1  32.00      0      0    8.3625         1
# 67          0               3    1  19.00      0      0    8.1583         1
# 833         0               3    1  23.00      0      0    7.8542         1
# 412         1               1    0  33.00      1      0   90.0000         3
# 547         1               2    1  28.00      0      0   13.8625         2
# 683         0               3    1  14.00      5      2   46.9000         1
# 685         0               2    1  25.00      1      2   41.5792         2
# 383         1               1    0  35.00      1      0   52.0000         1
# 675         0               3    1  18.00      0      0    7.7750         1
# 41          0               2    0  27.00      1      0   21.0000         1
# 866         1               2    0  27.00      1      0   13.8583         2
# 737         1               1    1  35.00      0      0  512.3292         2
# 844         0               3    1  17.00      0      0    8.6625         1
# 365         0               3    1  30.00      0      0    7.2500         1
# 90          0               3    1  29.00      0      0    8.0500         1
# 150         0               2    1  51.00      0      0   12.5250         1
# 475         0               1    1  28.00      0      0   52.0000         1
# 649         1               3    0  23.00      0      0    7.5500         1
# 157         0               3    1  30.00      0      0    8.0500         1
# 405         0               2    1  34.00      1      0   21.0000         1
# 663         0               3    1  36.00      0      0    7.4958         1
# 193         1               2    1   3.00      1      1   26.0000         1
# 636         0               3    1  32.00      0      0    7.9250         1
# 691         1               3    0   4.00      0      1   13.4167         2
#
#      CurrentAge        Disc  DeparturePort      Fare_Category  \
# 465      128.00    1.762500              1    (-0.001, 7.854]
# 399      118.00    3.162500              1     (10.5, 21.317]
# 93       116.00    5.143750              1     (10.5, 21.317]
# 407       93.00    4.687500              1     (10.5, 21.317]
# 1        125.00   17.820825              2  (39.688, 512.329]
# 867      121.00   12.623950              1  (39.688, 512.329]
# 725      110.00    2.165625              1      (7.854, 10.5]
# 236      134.00    6.500000              1   (21.317, 39.688]
# 130      123.00    1.973950              2      (7.854, 10.5]
# 55       118.00    8.875000              1   (21.317, 39.688]
# 537      120.00   26.606250              2  (39.688, 512.329]
# 4         90.35    2.012500              1      (7.854, 10.5]
# 319      130.00   33.625000              2  (39.688, 512.329]
# 293      114.00    2.212500              1      (7.854, 10.5]
# 851      164.00    1.943750              1    (-0.001, 7.854]
# 393      113.00   28.318750              2  (39.688, 512.329]
# 375      118.00   20.542700              2  (39.688, 512.329]
# 406      141.00    1.937500              1    (-0.001, 7.854]
# 317      144.00    3.500000              1     (10.5, 21.317]
# 720       96.00    8.250000              1   (21.317, 39.688]
# 768      118.00    6.037500              3   (21.317, 39.688]
# 802      101.00   30.000000              1  (39.688, 512.329]
# 840      110.00    1.981250              1      (7.854, 10.5]
# 462      137.00    9.625000              1   (21.317, 39.688]
# 45       118.00    2.012500              1      (7.854, 10.5]
# 644       90.75    4.814575              2     (10.5, 21.317]
# 769      122.00    2.090625              1      (7.854, 10.5]
# 67       109.00    2.039575              1      (7.854, 10.5]
# 833      113.00    1.963550              1    (-0.001, 7.854]
# 412      123.00   22.500000              3  (39.688, 512.329]
# 547      118.00    3.465625              2     (10.5, 21.317]
# 683      104.00   11.725000              1  (39.688, 512.329]
# 685      115.00   10.394800              2  (39.688, 512.329]
# 383      125.00   13.000000              1  (39.688, 512.329]
# 675      108.00    1.943750              1    (-0.001, 7.854]
# 41       117.00    5.250000              1     (10.5, 21.317]
# 866      117.00    3.464575              2     (10.5, 21.317]
# 737      125.00  128.082300              2  (39.688, 512.329]
# 844      107.00    2.165625              1      (7.854, 10.5]
# 365      120.00    1.812500              1    (-0.001, 7.854]
# 90       119.00    2.012500              1      (7.854, 10.5]
# 150      141.00    3.131250              1     (10.5, 21.317]
# 475      118.00   13.000000              1  (39.688, 512.329]
# 649      113.00    1.887500              1    (-0.001, 7.854]
# 157      120.00    2.012500              1      (7.854, 10.5]
# 405      124.00    5.250000              1     (10.5, 21.317]
# 663      126.00    1.873950              1    (-0.001, 7.854]
# 193       93.00    6.500000              1   (21.317, 39.688]
# 636      122.00    1.981250              1      (7.854, 10.5]
# 691       94.00    3.354175              2     (10.5, 21.317]
#
#     Fare_Category_Labels
# 465                    1
# 399                    3
# 93                     3
# 407                    3
# 1                      5
# 867                    5
# 725                    2
# 236                    4
# 130                    2
# 55                     4
# 537                    5
# 4                      2
# 319                    5
# 293                    2
# 851                    1
# 393                    5
# 375                    5
# 406                    1
# 317                    3
# 720                    4
# 768                    4
# 802                    5
# 840                    2
# 462                    4
# 45                     2
# 644                    3
# 769                    2
# 67                     2
# 833                    1
# 412                    5
# 547                    3
# 683                    5
# 685                    5
# 383                    5
# 675                    1
# 41                     3
# 866                    3
# 737                    5
# 844                    2
# 365                    1
# 90                     2
# 150                    3
# 475                    5
# 649                    1
# 157                    2
# 405                    3
# 663                    1
# 193                    4
# 636                    2
# 691                    3

# %%
# apply sorting (descending, ascending)
ti_50.sort_values(by = 'Age')
# Out:
#      Survived  PassengerClass  Sex    Age  SibSp  Parch      Fare  Embarked  \
# 4           0               3    1   0.35      0      0    8.0500         1
# 644         1               3    0   0.75      2      1   19.2583         2
# 193         1               2    1   3.00      1      1   26.0000         1
# 407         1               2    1   3.00      1      1   18.7500         1
# 691         1               3    0   4.00      0      1   13.4167         2
# 720         1               2    0   6.00      0      1   33.0000         1
# 802         1               1    1  11.00      1      2  120.0000         1
# 683         0               3    1  14.00      5      2   46.9000         1
# 844         0               3    1  17.00      0      0    8.6625         1
# 675         0               3    1  18.00      0      0    7.7750         1
# 67          0               3    1  19.00      0      0    8.1583         1
# 840         0               3    1  20.00      0      0    7.9250         1
# 725         0               3    1  20.00      0      0    8.6625         1
# 833         0               3    1  23.00      0      0    7.8542         1
# 649         1               3    0  23.00      0      0    7.5500         1
# 393         1               1    0  23.00      1      0  113.2750         2
# 293         0               3    0  24.00      0      0    8.8500         1
# 685         0               2    1  25.00      1      2   41.5792         2
# 93          0               3    1  26.00      1      2   20.5750         1
# 41          0               2    0  27.00      1      0   21.0000         1
# 866         1               2    0  27.00      1      0   13.8583         2
# 547         1               2    1  28.00      0      0   13.8625         2
# 475         0               1    1  28.00      0      0   52.0000         1
# 45          0               3    1  28.00      0      0    8.0500         1
# 768         0               3    1  28.00      1      0   24.1500         3
# 399         1               2    0  28.00      0      0   12.6500         1
# 375         1               1    0  28.00      1      0   82.1708         2
# 55          1               1    1  28.00      0      0   35.5000         1
# 90          0               3    1  29.00      0      0    8.0500         1
# 157         0               3    1  30.00      0      0    8.0500         1
# 365         0               3    1  30.00      0      0    7.2500         1
# 537         1               1    0  30.00      0      0  106.4250         2
# 867         0               1    1  31.00      0      0   50.4958         1
# 636         0               3    1  32.00      0      0    7.9250         1
# 769         0               3    1  32.00      0      0    8.3625         1
# 130         0               3    1  33.00      0      0    7.8958         2
# 412         1               1    0  33.00      1      0   90.0000         3
# 405         0               2    1  34.00      1      0   21.0000         1
# 737         1               1    1  35.00      0      0  512.3292         2
# 1           1               1    0  35.00      1      0   71.2833         2
# 383         1               1    0  35.00      1      0   52.0000         1
# 663         0               3    1  36.00      0      0    7.4958         1
# 465         0               3    1  38.00      0      0    7.0500         1
# 319         1               1    0  40.00      1      1  134.5000         2
# 236         0               2    1  44.00      1      0   26.0000         1
# 462         0               1    1  47.00      0      0   38.5000         1
# 150         0               2    1  51.00      0      0   12.5250         1
# 406         0               3    1  51.00      0      0    7.7500         1
# 317         0               2    1  54.00      0      0   14.0000         1
# 851         0               3    1  74.00      0      0    7.7750         1
#
#      CurrentAge        Disc  DeparturePort      Fare_Category  \
# 4         90.35    2.012500              1      (7.854, 10.5]
# 644       90.75    4.814575              2     (10.5, 21.317]
# 193       93.00    6.500000              1   (21.317, 39.688]
# 407       93.00    4.687500              1     (10.5, 21.317]
# 691       94.00    3.354175              2     (10.5, 21.317]
# 720       96.00    8.250000              1   (21.317, 39.688]
# 802      101.00   30.000000              1  (39.688, 512.329]
# 683      104.00   11.725000              1  (39.688, 512.329]
# 844      107.00    2.165625              1      (7.854, 10.5]
# 675      108.00    1.943750              1    (-0.001, 7.854]
# 67       109.00    2.039575              1      (7.854, 10.5]
# 840      110.00    1.981250              1      (7.854, 10.5]
# 725      110.00    2.165625              1      (7.854, 10.5]
# 833      113.00    1.963550              1    (-0.001, 7.854]
# 649      113.00    1.887500              1    (-0.001, 7.854]
# 393      113.00   28.318750              2  (39.688, 512.329]
# 293      114.00    2.212500              1      (7.854, 10.5]
# 685      115.00   10.394800              2  (39.688, 512.329]
# 93       116.00    5.143750              1     (10.5, 21.317]
# 41       117.00    5.250000              1     (10.5, 21.317]
# 866      117.00    3.464575              2     (10.5, 21.317]
# 547      118.00    3.465625              2     (10.5, 21.317]
# 475      118.00   13.000000              1  (39.688, 512.329]
# 45       118.00    2.012500              1      (7.854, 10.5]
# 768      118.00    6.037500              3   (21.317, 39.688]
# 399      118.00    3.162500              1     (10.5, 21.317]
# 375      118.00   20.542700              2  (39.688, 512.329]
# 55       118.00    8.875000              1   (21.317, 39.688]
# 90       119.00    2.012500              1      (7.854, 10.5]
# 157      120.00    2.012500              1      (7.854, 10.5]
# 365      120.00    1.812500              1    (-0.001, 7.854]
# 537      120.00   26.606250              2  (39.688, 512.329]
# 867      121.00   12.623950              1  (39.688, 512.329]
# 636      122.00    1.981250              1      (7.854, 10.5]
# 769      122.00    2.090625              1      (7.854, 10.5]
# 130      123.00    1.973950              2      (7.854, 10.5]
# 412      123.00   22.500000              3  (39.688, 512.329]
# 405      124.00    5.250000              1     (10.5, 21.317]
# 737      125.00  128.082300              2  (39.688, 512.329]
# 1        125.00   17.820825              2  (39.688, 512.329]
# 383      125.00   13.000000              1  (39.688, 512.329]
# 663      126.00    1.873950              1    (-0.001, 7.854]
# 465      128.00    1.762500              1    (-0.001, 7.854]
# 319      130.00   33.625000              2  (39.688, 512.329]
# 236      134.00    6.500000              1   (21.317, 39.688]
# 462      137.00    9.625000              1   (21.317, 39.688]
# 150      141.00    3.131250              1     (10.5, 21.317]
# 406      141.00    1.937500              1    (-0.001, 7.854]
# 317      144.00    3.500000              1     (10.5, 21.317]
# 851      164.00    1.943750              1    (-0.001, 7.854]
#
#     Fare_Category_Labels
# 4                      2
# 644                    3
# 193                    4
# 407                    3
# 691                    3
# 720                    4
# 802                    5
# 683                    5
# 844                    2
# 675                    1
# 67                     2
# 840                    2
# 725                    2
# 833                    1
# 649                    1
# 393                    5
# 293                    2
# 685                    5
# 93                     3
# 41                     3
# 866                    3
# 547                    3
# 475                    5
# 45                     2
# 768                    4
# 399                    3
# 375                    5
# 55                     4
# 90                     2
# 157                    2
# 365                    1
# 537                    5
# 867                    5
# 636                    2
# 769                    2
# 130                    2
# 412                    5
# 405                    3
# 737                    5
# 1                      5
# 383                    5
# 663                    1
# 465                    1
# 319                    5
# 236                    4
# 462                    4
# 150                    3
# 406                    1
# 317                    3
# 851                    1

# %%
ti_50.sort_values(by = 'Age', ascending = False)
# Out:
#      Survived  PassengerClass  Sex    Age  SibSp  Parch      Fare  Embarked  \
# 851         0               3    1  74.00      0      0    7.7750         1
# 317         0               2    1  54.00      0      0   14.0000         1
# 150         0               2    1  51.00      0      0   12.5250         1
# 406         0               3    1  51.00      0      0    7.7500         1
# 462         0               1    1  47.00      0      0   38.5000         1
# 236         0               2    1  44.00      1      0   26.0000         1
# 319         1               1    0  40.00      1      1  134.5000         2
# 465         0               3    1  38.00      0      0    7.0500         1
# 663         0               3    1  36.00      0      0    7.4958         1
# 383         1               1    0  35.00      1      0   52.0000         1
# 1           1               1    0  35.00      1      0   71.2833         2
# 737         1               1    1  35.00      0      0  512.3292         2
# 405         0               2    1  34.00      1      0   21.0000         1
# 130         0               3    1  33.00      0      0    7.8958         2
# 412         1               1    0  33.00      1      0   90.0000         3
# 769         0               3    1  32.00      0      0    8.3625         1
# 636         0               3    1  32.00      0      0    7.9250         1
# 867         0               1    1  31.00      0      0   50.4958         1
# 365         0               3    1  30.00      0      0    7.2500         1
# 157         0               3    1  30.00      0      0    8.0500         1
# 537         1               1    0  30.00      0      0  106.4250         2
# 90          0               3    1  29.00      0      0    8.0500         1
# 768         0               3    1  28.00      1      0   24.1500         3
# 475         0               1    1  28.00      0      0   52.0000         1
# 375         1               1    0  28.00      1      0   82.1708         2
# 45          0               3    1  28.00      0      0    8.0500         1
# 399         1               2    0  28.00      0      0   12.6500         1
# 55          1               1    1  28.00      0      0   35.5000         1
# 547         1               2    1  28.00      0      0   13.8625         2
# 866         1               2    0  27.00      1      0   13.8583         2
# 41          0               2    0  27.00      1      0   21.0000         1
# 93          0               3    1  26.00      1      2   20.5750         1
# 685         0               2    1  25.00      1      2   41.5792         2
# 293         0               3    0  24.00      0      0    8.8500         1
# 833         0               3    1  23.00      0      0    7.8542         1
# 393         1               1    0  23.00      1      0  113.2750         2
# 649         1               3    0  23.00      0      0    7.5500         1
# 725         0               3    1  20.00      0      0    8.6625         1
# 840         0               3    1  20.00      0      0    7.9250         1
# 67          0               3    1  19.00      0      0    8.1583         1
# 675         0               3    1  18.00      0      0    7.7750         1
# 844         0               3    1  17.00      0      0    8.6625         1
# 683         0               3    1  14.00      5      2   46.9000         1
# 802         1               1    1  11.00      1      2  120.0000         1
# 720         1               2    0   6.00      0      1   33.0000         1
# 691         1               3    0   4.00      0      1   13.4167         2
# 193         1               2    1   3.00      1      1   26.0000         1
# 407         1               2    1   3.00      1      1   18.7500         1
# 644         1               3    0   0.75      2      1   19.2583         2
# 4           0               3    1   0.35      0      0    8.0500         1
#
#      CurrentAge        Disc  DeparturePort      Fare_Category  \
# 851      164.00    1.943750              1    (-0.001, 7.854]
# 317      144.00    3.500000              1     (10.5, 21.317]
# 150      141.00    3.131250              1     (10.5, 21.317]
# 406      141.00    1.937500              1    (-0.001, 7.854]
# 462      137.00    9.625000              1   (21.317, 39.688]
# 236      134.00    6.500000              1   (21.317, 39.688]
# 319      130.00   33.625000              2  (39.688, 512.329]
# 465      128.00    1.762500              1    (-0.001, 7.854]
# 663      126.00    1.873950              1    (-0.001, 7.854]
# 383      125.00   13.000000              1  (39.688, 512.329]
# 1        125.00   17.820825              2  (39.688, 512.329]
# 737      125.00  128.082300              2  (39.688, 512.329]
# 405      124.00    5.250000              1     (10.5, 21.317]
# 130      123.00    1.973950              2      (7.854, 10.5]
# 412      123.00   22.500000              3  (39.688, 512.329]
# 769      122.00    2.090625              1      (7.854, 10.5]
# 636      122.00    1.981250              1      (7.854, 10.5]
# 867      121.00   12.623950              1  (39.688, 512.329]
# 365      120.00    1.812500              1    (-0.001, 7.854]
# 157      120.00    2.012500              1      (7.854, 10.5]
# 537      120.00   26.606250              2  (39.688, 512.329]
# 90       119.00    2.012500              1      (7.854, 10.5]
# 768      118.00    6.037500              3   (21.317, 39.688]
# 475      118.00   13.000000              1  (39.688, 512.329]
# 375      118.00   20.542700              2  (39.688, 512.329]
# 45       118.00    2.012500              1      (7.854, 10.5]
# 399      118.00    3.162500              1     (10.5, 21.317]
# 55       118.00    8.875000              1   (21.317, 39.688]
# 547      118.00    3.465625              2     (10.5, 21.317]
# 866      117.00    3.464575              2     (10.5, 21.317]
# 41       117.00    5.250000              1     (10.5, 21.317]
# 93       116.00    5.143750              1     (10.5, 21.317]
# 685      115.00   10.394800              2  (39.688, 512.329]
# 293      114.00    2.212500              1      (7.854, 10.5]
# 833      113.00    1.963550              1    (-0.001, 7.854]
# 393      113.00   28.318750              2  (39.688, 512.329]
# 649      113.00    1.887500              1    (-0.001, 7.854]
# 725      110.00    2.165625              1      (7.854, 10.5]
# 840      110.00    1.981250              1      (7.854, 10.5]
# 67       109.00    2.039575              1      (7.854, 10.5]
# 675      108.00    1.943750              1    (-0.001, 7.854]
# 844      107.00    2.165625              1      (7.854, 10.5]
# 683      104.00   11.725000              1  (39.688, 512.329]
# 802      101.00   30.000000              1  (39.688, 512.329]
# 720       96.00    8.250000              1   (21.317, 39.688]
# 691       94.00    3.354175              2     (10.5, 21.317]
# 193       93.00    6.500000              1   (21.317, 39.688]
# 407       93.00    4.687500              1     (10.5, 21.317]
# 644       90.75    4.814575              2     (10.5, 21.317]
# 4         90.35    2.012500              1      (7.854, 10.5]
#
#     Fare_Category_Labels
# 851                    1
# 317                    3
# 150                    3
# 406                    1
# 462                    4
# 236                    4
# 319                    5
# 465                    1
# 663                    1
# 383                    5
# 1                      5
# 737                    5
# 405                    3
# 130                    2
# 412                    5
# 769                    2
# 636                    2
# 867                    5
# 365                    1
# 157                    2
# 537                    5
# 90                     2
# 768                    4
# 475                    5
# 375                    5
# 45                     2
# 399                    3
# 55                     4
# 547                    3
# 866                    3
# 41                     3
# 93                     3
# 685                    5
# 293                    2
# 833                    1
# 393                    5
# 649                    1
# 725                    2
# 840                    2
# 67                     2
# 675                    1
# 844                    2
# 683                    5
# 802                    5
# 720                    4
# 691                    3
# 193                    4
# 407                    3
# 644                    3
# 4                      2

# %% [markdown]
# References
# - [Cleaning Big Data: Most Time-Consuming, Least Enjoyable Data Science Task, Survey Says](http://www.forbes.com/sites/gilpress/2016/03/23/data-preparation-most-time-consuming-least-enjoyable-data-science-task-survey-says/#62eb1cc37f75)
